# %%
# display output from every line without explicit print()
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pathlib
import pandas as pd
import plotnine as pn
import requests
import bs4
import re

# %%
contributions_path = pathlib.Path('./webl22.txt')

contributions_df = pd.read_csv(contributions_path, sep = '|', header = None,
                               names = ['CAND_ID',
                                        'CAND_NAME',
                                        'CAND_ICI',
                                        'PTY_CD',
                                        'CAND_PTY_AFFILIATION',
                                        'TTL_RECEIPTS',
                                        'TRANS_FROM_AUTH',
                                        'TTL_DISB',
                                        'TRANS_TO_AUTH',
                                        'COH_BOP',
                                        'COH_COP',
                                        'CAND_CONTRIB',
                                        'CAND_LOANS',
                                        'OTHER_LOANS',
                                        'CAND_LOAN_REPAY',
                                        'OTHER_LOAN_REPAY',
                                        'DEBTS_OWED_BY',
                                        'TTL_INDIV_CONTRIB',
                                        'CAND_OFFICE_ST',
                                        'CAND_OFFICE_DISTRICT',
                                        'SPEC_ELECTION',
                                        'PRIM_ELECTION',
                                        'RUN_ELECTION',
                                        'GEN_ELECTION',
                                        'GEN_ELECTION_PRECENT',
                                        'OTHER_POL_CMTE_CONTRIB',
                                        'POL_PTY_CONTRIB',
                                        'CVG_END_DT',
                                        'INDIV_REFUNDS',
                                        'CMTE_REFUNDS'
                                       ]
                              )

# %%
contributions_df
# Out:
#         CAND_ID                 CAND_NAME CAND_ICI  PTY_CD  \
# 0     H2AK00200     CONSTANT, CHRISTOPHER        C       1
# 1     H2AK01158             PELTOLA, MARY        I       1
# 2     H2AK01240              WOOL, ADAM L        O       1
# 3     H2AK00218        REVAK, JOSHUA CARL        O       2
# 4     H2AK00226              PALIN, SARAH        O       2
# ...         ...                       ...      ...     ...
# 2843  S2WI00466  WILLIAMS, DARRELL L. DR.        C       1
# 2844  S0WI00197   JOHNSON, RON HAROLD MR.        I       2
# 2845  S2WI00482               BEYER, BRAD        C       2
# 2846  S2WI00508      BENEDETTO, ADAM SIIK        C       2
# 2847  S2WI00516                LONG, NEAL        C       3
#
#      CAND_PTY_AFFILIATION  TTL_RECEIPTS  TRANS_FROM_AUTH     TTL_DISB  \
# 0                     DEM     164637.90             0.00    164037.51
# 1                     DEM    5785806.88        144363.90   3364338.19
# ...
